# %%
import pandas as pd
import numpy as np

# %%
h1bdat = pd.read_excel("../h1b/H-1B_Disclosure_Data_FY17.xlsx")

# %%
#ziploc = pd.read_csv("Georeferences/zip tabulation area/2017_zip_tabulation_areas_gazetteer.txt", sep="\t", converters = {"GEOID": lambda x: str(x)})
zipref = pd.read_excel("../cross-walk/ZIP_COUNTY_122017.xlsx")

# %%
len(ziploc) #33144
len(h1bdat) #624650
list(h1ba)
# Out:
# ['CASE_NUMBER',
#  'CASE_STATUS',
#  'CASE_SUBMITTED',
#  'DECISION_DATE',
#  'VISA_CLASS',
#  'EMPLOYMENT_START_DATE',
#  'EMPLOYMENT_END_DATE',
#  'EMPLOYER_NAME',
#  'EMPLOYER_BUSINESS_DBA',
#  'EMPLOYER_ADDRESS',
#  'EMPLOYER_CITY',
#  'EMPLOYER_STATE',
#  'EMPLOYER_POSTAL_CODE',
#  'EMPLOYER_COUNTRY',
#  'EMPLOYER_PROVINCE',
#  'EMPLOYER_PHONE',
#  'EMPLOYER_PHONE_EXT',
#  'AGENT_REPRESENTING_EMPLOYER',
#  'AGENT_ATTORNEY_NAME',
#  'AGENT_ATTORNEY_CITY',
#  'AGENT_ATTORNEY_STATE',
#  'JOB_TITLE',
#  'SOC_CODE',
#  'SOC_NAME',
#  'NAICS_CODE',
#  'TOTAL_WORKERS',
#  'NEW_EMPLOYMENT',
#  'CONTINUED_EMPLOYMENT',
#  'CHANGE_PREVIOUS_EMPLOYMENT',
#  'NEW_CONCURRENT_EMPLOYMENT',
#  'CHANGE_EMPLOYER',
#  'AMENDED_PETITION',
#  'FULL_TIME_POSITION',
#  'PREVAILING_WAGE',
#  'PW_UNIT_OF_PAY',
#  'PW_WAGE_LEVEL',
#  'PW_SOURCE',
#  'PW_SOURCE_YEAR',
#  'PW_SOURCE_OTHER',
#  'WAGE_RATE_OF_PAY_FROM',
#  'WAGE_RATE_OF_PAY_TO',
#  'WAGE_UNIT_OF_PAY',
#  'H1B_DEPENDENT',
# ...

# %%
#h1ba = h1bdat
#list(h1bdat)
h1ba['CASE_STATUS'] = h1ba['CASE_STATUS'].astype('category')
h1ba['VISA_CLASS'] = h1ba['VISA_CLASS'].astype('category')

# %%
h1ba = h1ba[['CASE_NUMBER','CASE_STATUS','CASE_SUBMITTED','DECISION_DATE',
'VISA_CLASS','EMPLOYMENT_START_DATE','EMPLOYMENT_END_DATE','EMPLOYER_NAME','EMPLOYER_CITY',
 'EMPLOYER_STATE','EMPLOYER_POSTAL_CODE','JOB_TITLE','NAICS_CODE','TOTAL_WORKERS','WORKSITE_CITY',
    'WORKSITE_COUNTY','WORKSITE_STATE','WORKSITE_POSTAL_CODE','ORIGINAL_CERT_DATE']]

# %%
h1ba.head()
# Out:
#           CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16055-173457  CERTIFIED-WITHDRAWN     2016-02-24    2016-10-01
# 1  I-200-16064-557834  CERTIFIED-WITHDRAWN     2016-03-04    2016-10-01
# 2  I-200-16063-996093  CERTIFIED-WITHDRAWN     2016-03-10    2016-10-01
# 3  I-200-16272-196340            WITHDRAWN     2016-09-28    2016-10-01
# 4  I-200-15053-636744  CERTIFIED-WITHDRAWN     2015-02-22    2016-10-02
#
#   VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0       H-1B            2016-08-10          2019-08-10
# 1       H-1B            2016-08-16          2019-08-16
# 2       H-1B            2016-09-09          2019-09-09
# 3       H-1B            2017-01-26          2020-01-25
# 4       H-1B            2015-03-01          2018-03-01
#
#                EMPLOYER_NAME EMPLOYER_CITY EMPLOYER_STATE  \
# 0     DISCOVER PRODUCTS INC.    RIVERWOODS             IL
# 1           DFS SERVICES LLC    RIVERWOODS             IL
# ...

# %%
h1ba[['CASE_SUBMITTED','DECISION_DATE','EMPLOYMENT_START_DATE','EMPLOYMENT_END_DATE','ORIGINAL_CERT_DATE']] = h1ba[['CASE_SUBMITTED','DECISION_DATE','EMPLOYMENT_START_DATE','EMPLOYMENT_END_DATE','ORIGINAL_CERT_DATE']].astype('datetime64[ns]')
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:2540: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
h1ba.dtypes
# Out:
# CASE_NUMBER                      object
# CASE_STATUS                    category
# CASE_SUBMITTED           datetime64[ns]
# DECISION_DATE            datetime64[ns]
# VISA_CLASS                     category
# EMPLOYMENT_START_DATE    datetime64[ns]
# EMPLOYMENT_END_DATE      datetime64[ns]
# EMPLOYER_NAME                    object
# EMPLOYER_CITY                    object
# EMPLOYER_STATE                   object
# EMPLOYER_POSTAL_CODE             object
# JOB_TITLE                        object
# NAICS_CODE                       object
# TOTAL_WORKERS                     int64
# WORKSITE_CITY                    object
# WORKSITE_COUNTY                  object
# WORKSITE_STATE                   object
# WORKSITE_POSTAL_CODE             object
# ORIGINAL_CERT_DATE       datetime64[ns]
# dtype: object

# %%
# total number of states visas were issued to: 
# by employer location
h1ba[h1ba['EMPLOYER_CITY'] != h1ba['WORKSITE_CITY']].sum()

# %%
h1ba.groupby(['VISA_CLASS','CASE_STATUS']).agg(['mean','count'])
# Out:
#                                     TOTAL_WORKERS
#                                              mean   count
# VISA_CLASS      CASE_STATUS
# E-3 Australian  CERTIFIED                1.134812   10192
#                 CERTIFIED-WITHDRAWN      1.179487     702
#                 DENIED                   1.044521     876
#                 WITHDRAWN                1.095607     387
# H-1B            CERTIFIED                1.979328  533621
#                 CERTIFIED-WITHDRAWN      1.285311   48880
#                 DENIED                   2.441251    7481
#                 WITHDRAWN                1.444986   20322
# H-1B1 Chile     CERTIFIED                1.071970     792
#                 CERTIFIED-WITHDRAWN      1.062500      48
#                 DENIED                   1.000000      69
#                 WITHDRAWN                1.000000      26
# H-1B1 Singapore CERTIFIED                1.283747    1089
#                 CERTIFIED-WITHDRAWN      1.013514      74
# ...

# %%
h1ba.groupby(['CASE_STATUS','VISA_CLASS']).agg(['mean','count'])
# Out:
#                                     TOTAL_WORKERS
#                                              mean   count
# CASE_STATUS         VISA_CLASS
# CERTIFIED           E-3 Australian       1.134812   10192
#                     H-1B                 1.979328  533621
#                     H-1B1 Chile          1.071970     792
#                     H-1B1 Singapore      1.283747    1089
# CERTIFIED-WITHDRAWN E-3 Australian       1.179487     702
#                     H-1B                 1.285311   48880
#                     H-1B1 Chile          1.062500      48
#                     H-1B1 Singapore      1.013514      74
# DENIED              E-3 Australian       1.044521     876
#                     H-1B                 2.441251    7481
#                     H-1B1 Chile          1.000000      69
#                     H-1B1 Singapore      1.055556      54
# WITHDRAWN           E-3 Australian       1.095607     387
#                     H-1B                 1.444986   20322
# ...

# %%
h1ba.groupby(['WORKSITE_STATE']).agg(['mean','count'])
# Out:
#                TOTAL_WORKERS
#                         mean   count
# WORKSITE_STATE
# AK                  1.303922     204
# AL                  1.530836    1735
# AR                  1.656958    2781
# AZ                  1.700942    9453
# CA                  2.288144  119409
# CO                  2.211223    6576
# CT                  2.074019    8133
# DC                  1.644302    4203
# DE                  1.674107    3360
# FL                  1.944213   21815
# FM                  1.000000       1
# GA                  1.697127   22521
# GU                  1.076246     341
# HI                  1.490942     552
# IA                  1.674637    3095
# ID                  1.786041     874
# IL                  1.796553   32082
# IN                  1.779558    6115
# KS                  1.638787    2738
# KY                  1.991241    2626
# LA                  1.548636    1943
# MA                  1.601615   25016
# MD                  1.436188   10672
# ...

# %%
len(h1ba['WORKSITE_POSTAL_CODE'].unique()) 
#1 in 2 zipcodes!
# Out:
# 15146

# %%
zipref = ziploc = pd.read_csv("Georeferences/cross-walk/"
# Out:
#                   TOTAL_WORKERS
#                            mean count
# WORKSITE_COUNTY
# $67,184                1.000000     1
# &NBSP;SANTA CLARA      1.000000     2
# 'USA'                  1.000000     1
# (DALLAS                1.000000     1
# -.                     1.000000     1
# .JOHNSON               1.000000     1
# 02110                  1.000000     1
# 02169                  1.000000     1
# 02920                  1.000000     1
# 07068                  1.000000     1
# 07632                  1.000000     1
# 08807                  4.000000     1
# 0ZAUKEE                1.000000     1
# 10577                  1.000000     1
# 14414                  1.000000     1
# 200 VESEY STREET       2.000000     1
# 20817                  1.000000     2
# 22182                  1.000000     1
# 25025                  1.000000     1
# 27710                  1.000000     1
# 30309                  1.000000     1
# 33610                  1.000000     6
# ...
